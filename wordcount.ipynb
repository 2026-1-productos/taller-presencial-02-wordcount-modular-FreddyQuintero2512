# %%
# obtain a list of files in the input directory
import os
import os.path

files_in_input_dir=os.listdir('data/input/')
files_in_input_dir
# Out:
# ['file4.txt', 'file1.txt', 'file2.txt', 'file3.txt']

# %%
# count the frequency of the words in the files in the input directory
counter={}
for filename in files_in_input_dir:
    with open('data/input/'+filename) as f:
        for l in f:
            for w in l.split( ):
                w = w.lower().strip(",.!?")
                counter[w] = counter.get(w, 0) + 1

# %%
# create the directory output/ if it doesn't exist
if not os.path.exists('data/output'):
    os.makedirs('data/output')

# save the results using tsv format
with open("data/output/results.tsv", "w", encoding="utf-8") as f:
        for key, value in counter.items():
            # write the key and value to the file
            f.write(f"{key}\t{value}\n")

# %%
def read_file_from_folder(input_folder):
    return os.listdir(input_folder)

# %%
def process_input_files(input_folder, files):

    counter={}
    for file in files: 
        path    = os.path.join(input_folder, file)
        counter = process_file(file, counter)
    return counter

def process_file(file, counter):
    with open(file, "r", encoding="utf-8") as f:
        for l in f:
            for w in l.split( ):
                w = w.lower().strip(",.!?")
                counter[w] = counter.get(w, 0) + 1

# %%
def create_output_folder(output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
